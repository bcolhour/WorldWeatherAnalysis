# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs =zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 736

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=88ddd52aa656b155c98c39ac490d5d30

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | macomer
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | codrington
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | oranjemund
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 9 of Set 1 | saint-pierre
# Processing Record 10 of Set 1 | changji
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | ulladulla
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | paamiut
# Processing Record 18 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | gisborne
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | flin flon
# Processing Record 28 of Set 1 | egvekinot
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | orel-izumrud
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | padang
# Processing Record 35 of Set 1 | duiwelskloof
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | umm kaddadah
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | kingman
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | cabedelo
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | markova
# Processing Record 45 of Set 1 | xining
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | taoudenni
# Processing Record 48 of Set 1 | bend
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | port macquarie
# Processing Record 3 of Set 2 | wajima
# Processing Record 4 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 2 | mogocha
# Processing Record 6 of Set 2 | fort nelson
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | perumpavur
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | rincon
# Processing Record 12 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 13 of Set 2 | seymchan
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | moerai
# Processing Record 16 of Set 2 | murray bridge
# Processing Record 17 of Set 2 | adamas
# Processing Record 18 of Set 2 | souillac
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | buraydah
# Processing Record 21 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | ulagan
# Processing Record 24 of Set 2 | batagay-alyta
# Processing Record 25 of Set 2 | saint-paul
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | cairns
# Processing Record 29 of Set 2 | tiznit
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | kavieng
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | cajati
# Processing Record 35 of Set 2 | lisakovsk
# Processing Record 36 of Set 2 | chernushka
# Processing Record 37 of Set 2 | dunedin
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 | ternate
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | san jose
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | ruteng
# Processing Record 45 of Set 2 | chirongui
# Processing Record 46 of Set 2 | malangwa
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 3 | reconquista
# Processing Record 3 of Set 3 | port hedland
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | mayo
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | ambilobe
# Processing Record 8 of Set 3 | yongan
# Processing Record 9 of Set 3 | tyrma
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | nathdwara
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | fairbanks
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | diamantina
# Processing Record 18 of Set 3 | tuktoyaktuk
# Processing Record 19 of Set 3 | makung
# City not found. Skipping...
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | lac-megantic
# Processing Record 23 of Set 3 | teknaf
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | komsomolskiy
# Processing Record 26 of Set 3 | muros
# Processing Record 27 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | tasiilaq
# Processing Record 32 of Set 3 | alenquer
# Processing Record 33 of Set 3 | sarmanovo
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | zanjan
# Processing Record 39 of Set 3 | asau
# Processing Record 40 of Set 3 | namibe
# Processing Record 41 of Set 3 | luderitz
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | angoram
# Processing Record 44 of Set 3 | pedernales
# Processing Record 45 of Set 3 | biak
# Processing Record 46 of Set 3 | praia da vitoria
# Processing Record 47 of Set 3 | kulhudhuffushi
# Processing Record 48 of Set 3 | constitucion
# Processing Record 49 of Set 3 | ust-barguzin
# Processing Record 50 of Set 3 | soe
# Processing Record 1 of Set 4 | vizinga
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | bermeo
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | kawai
# Processing Record 6 of Set 4 | katsuura
# Processing Record 7 of Set 4 | yulara
# Processing Record 8 of Set 4 | gornopravdinsk
# Processing Record 9 of Set 4 | cururupu
# Processing Record 10 of Set 4 | aquiraz
# Processing Record 11 of Set 4 | ahtopol
# Processing Record 12 of Set 4 | hovd
# Processing Record 13 of Set 4 | moyale
# Processing Record 14 of Set 4 | bathsheba
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | mercedes
# Processing Record 17 of Set 4 | andenes
# Processing Record 18 of Set 4 | domnesti
# Processing Record 19 of Set 4 | groningen
# Processing Record 20 of Set 4 | san pedro
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | zyryanka
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | varkkallai
# Processing Record 25 of Set 4 | comodoro rivadavia
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | nampula
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | saint-michel-des-saints
# Processing Record 30 of Set 4 | englehart
# Processing Record 31 of Set 4 | atuona
# Processing Record 32 of Set 4 | klyuchevskiy
# Processing Record 33 of Set 4 | elliot lake
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | nicoya
# Processing Record 37 of Set 4 | rorvik
# Processing Record 38 of Set 4 | vilhena
# Processing Record 39 of Set 4 | joshimath
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | leshukonskoye
# Processing Record 42 of Set 4 | harrogate
# Processing Record 43 of Set 4 | vostok
# Processing Record 44 of Set 4 | mount isa
# Processing Record 45 of Set 4 | mandali
# Processing Record 46 of Set 4 | ryotsu
# Processing Record 47 of Set 4 | adrar
# Processing Record 48 of Set 4 | nantucket
# Processing Record 49 of Set 4 | mahebourg
# Processing Record 50 of Set 4 | tilichiki
# Processing Record 1 of Set 5 | rabaul
# Processing Record 2 of Set 5 | kyzyl-suu
# Processing Record 3 of Set 5 | la ronge
# Processing Record 4 of Set 5 | mahon
# Processing Record 5 of Set 5 | bonavista
# Processing Record 6 of Set 5 | puerto madero
# Processing Record 7 of Set 5 | nadym
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | port shepstone
# Processing Record 11 of Set 5 | katherine
# Processing Record 12 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 13 of Set 5 | saint anthony
# Processing Record 14 of Set 5 | sola
# Processing Record 15 of Set 5 | bonfim
# Processing Record 16 of Set 5 | aginskoye
# Processing Record 17 of Set 5 | waitati
# Processing Record 18 of Set 5 | scottsbluff
# Processing Record 19 of Set 5 | yellowknife
# Processing Record 20 of Set 5 | tifton
# Processing Record 21 of Set 5 | ferrol
# Processing Record 22 of Set 5 | alushta
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | ribeira grande
# Processing Record 25 of Set 5 | port moresby
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | guiyang
# Processing Record 28 of Set 5 | san borja
# Processing Record 29 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 5 | sibolga
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 5 | lazaro cardenas
# Processing Record 37 of Set 5 | kvelde
# City not found. Skipping...
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | beoumi
# Processing Record 40 of Set 5 | victoria
# Processing Record 41 of Set 5 | bull savanna
# Processing Record 42 of Set 5 | songjianghe
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | byadgi
# Processing Record 45 of Set 5 | abha
# Processing Record 46 of Set 5 | paraiso
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | yaan
# Processing Record 50 of Set 5 | ao luk
# City not found. Skipping...
# Processing Record 1 of Set 6 | klimovo
# Processing Record 2 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 6 | boa vista
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 6 | maragogi
# Processing Record 7 of Set 6 | tocopilla
# Processing Record 8 of Set 6 | elko
# Processing Record 9 of Set 6 | whitehorse
# Processing Record 10 of Set 6 | brzesko
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | old saybrook
# Processing Record 13 of Set 6 | manokwari
# Processing Record 14 of Set 6 | touros
# Processing Record 15 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 6 | mugur-aksy
# Processing Record 17 of Set 6 | loiza
# Processing Record 18 of Set 6 | bodaybo
# Processing Record 19 of Set 6 | tianpeng
# Processing Record 20 of Set 6 | waingapu
# Processing Record 21 of Set 6 | oussouye
# Processing Record 22 of Set 6 | coquimbo
# Processing Record 23 of Set 6 | riberalta
# Processing Record 24 of Set 6 | khawhai
# Processing Record 25 of Set 6 | bethel
# Processing Record 26 of Set 6 | siguiri
# Processing Record 27 of Set 6 | arraial do cabo
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | acapulco
# Processing Record 31 of Set 6 | kavaratti
# Processing Record 32 of Set 6 | pampierstad
# Processing Record 33 of Set 6 | coos bay
# Processing Record 34 of Set 6 | lockhart
# Processing Record 35 of Set 6 | sao filipe
# Processing Record 36 of Set 6 | jeremie
# Processing Record 37 of Set 6 | hokitika
# Processing Record 38 of Set 6 | salinas
# Processing Record 39 of Set 6 | biltine
# Processing Record 40 of Set 6 | nabire
# Processing Record 41 of Set 6 | ust-tsilma
# Processing Record 42 of Set 6 | yar-sale
# Processing Record 43 of Set 6 | pochutla
# Processing Record 44 of Set 6 | cimislia
# Processing Record 45 of Set 6 | shimoda
# Processing Record 46 of Set 6 | saint-philippe
# Processing Record 47 of Set 6 | mareeba
# Processing Record 48 of Set 6 | ipixuna
# Processing Record 49 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | puerto del rosario
# Processing Record 1 of Set 7 | saint-francois
# Processing Record 2 of Set 7 | perth
# Processing Record 3 of Set 7 | chicama
# Processing Record 4 of Set 7 | torbay
# Processing Record 5 of Set 7 | dennery
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | puerto quijarro
# Processing Record 8 of Set 7 | chuy
# Processing Record 9 of Set 7 | polyarnyye zori
# Processing Record 10 of Set 7 | serebryansk
# Processing Record 11 of Set 7 | saskylakh
# Processing Record 12 of Set 7 | iquique
# Processing Record 13 of Set 7 | sarakhs
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | kahului
# Processing Record 16 of Set 7 | trinidad
# Processing Record 17 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 18 of Set 7 | hofn
# Processing Record 19 of Set 7 | ixtapa
# Processing Record 20 of Set 7 | cabra
# Processing Record 21 of Set 7 | kirakira
# Processing Record 22 of Set 7 | chifeng
# Processing Record 23 of Set 7 | tadine
# Processing Record 24 of Set 7 | palaikastron
# Processing Record 25 of Set 7 | kudahuvadhoo
# Processing Record 26 of Set 7 | belaya gora
# Processing Record 27 of Set 7 | tessalit
# Processing Record 28 of Set 7 | wahiawa
# Processing Record 29 of Set 7 | provideniya
# Processing Record 30 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 7 | sept-iles
# Processing Record 32 of Set 7 | lompoc
# Processing Record 33 of Set 7 | kanniyakumari
# Processing Record 34 of Set 7 | tevaitoa
# Processing Record 35 of Set 7 | lianran
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | turkistan
# Processing Record 38 of Set 7 | gilazi
# City not found. Skipping...
# Processing Record 39 of Set 7 | takestan
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | beringovskiy
# Processing Record 42 of Set 7 | portland
# Processing Record 43 of Set 7 | ambon
# Processing Record 44 of Set 7 | omsukchan
# Processing Record 45 of Set 7 | bermejo
# Processing Record 46 of Set 7 | yanji
# Processing Record 47 of Set 7 | marzuq
# Processing Record 48 of Set 7 | bratsk
# Processing Record 49 of Set 7 | megion
# Processing Record 50 of Set 7 | malgrat de mar
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | freeport
# Processing Record 3 of Set 8 | daru
# Processing Record 4 of Set 8 | diapaga
# Processing Record 5 of Set 8 | nsoko
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | pevek
# Processing Record 9 of Set 8 | ambatondrazaka
# Processing Record 10 of Set 8 | callaway
# Processing Record 11 of Set 8 | waghai
# Processing Record 12 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 13 of Set 8 | nishihara
# Processing Record 14 of Set 8 | canutama
# Processing Record 15 of Set 8 | husavik
# Processing Record 16 of Set 8 | boxmeer
# Processing Record 17 of Set 8 | quang ngai
# Processing Record 18 of Set 8 | sagar
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | aksay
# Processing Record 21 of Set 8 | abbeville
# Processing Record 22 of Set 8 | bambanglipuro
# Processing Record 23 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | berdigestyakh
# Processing Record 26 of Set 8 | north bend
# Processing Record 27 of Set 8 | airai
# Processing Record 28 of Set 8 | pakxan
# Processing Record 29 of Set 8 | lambare
# Processing Record 30 of Set 8 | vallenar
# Processing Record 31 of Set 8 | tiksi
# Processing Record 32 of Set 8 | traverse city
# Processing Record 33 of Set 8 | havelock
# Processing Record 34 of Set 8 | aksarka
# Processing Record 35 of Set 8 | aktau
# Processing Record 36 of Set 8 | nalobikha
# Processing Record 37 of Set 8 | rawson
# Processing Record 38 of Set 8 | mayumba
# Processing Record 39 of Set 8 | wanlaweyn
# Processing Record 40 of Set 8 | deniliquin
# Processing Record 41 of Set 8 | lashio
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | fayaoue
# Processing Record 44 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 8 | avera
# Processing Record 46 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | praxedis guerrero
# Processing Record 48 of Set 8 | sur
# Processing Record 49 of Set 8 | alvdal
# Processing Record 50 of Set 8 | gizo
# Processing Record 1 of Set 9 | ketchikan
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | nelson bay
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | culebra
# Processing Record 6 of Set 9 | ahipara
# Processing Record 7 of Set 9 | bertoua
# Processing Record 8 of Set 9 | meadow lake
# Processing Record 9 of Set 9 | shumikha
# Processing Record 10 of Set 9 | mattoon
# Processing Record 11 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 9 | norfolk
# Processing Record 13 of Set 9 | faya
# Processing Record 14 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 9 | santa cruz
# Processing Record 16 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 9 | sun city west
# Processing Record 18 of Set 9 | mahasamund
# Processing Record 19 of Set 9 | singaraja
# Processing Record 20 of Set 9 | tieling
# Processing Record 21 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 22 of Set 9 | bilibino
# Processing Record 23 of Set 9 | mumford
# Processing Record 24 of Set 9 | ocean city
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | kafanchan
# Processing Record 27 of Set 9 | dire
# Processing Record 28 of Set 9 | tanabi
# Processing Record 29 of Set 9 | arman
# Processing Record 30 of Set 9 | pangody
# Processing Record 31 of Set 9 | baykit
# Processing Record 32 of Set 9 | sampit
# Processing Record 33 of Set 9 | coihaique
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | yantal
# Processing Record 36 of Set 9 | synya
# Processing Record 37 of Set 9 | ginda
# Processing Record 38 of Set 9 | warrnambool
# Processing Record 39 of Set 9 | tezu
# Processing Record 40 of Set 9 | lagos
# Processing Record 41 of Set 9 | coahuayana
# Processing Record 42 of Set 9 | cap malheureux
# Processing Record 43 of Set 9 | trincomalee
# Processing Record 44 of Set 9 | vestmanna
# Processing Record 45 of Set 9 | moundou
# Processing Record 46 of Set 9 | nanning
# Processing Record 47 of Set 9 | solnechnyy
# Processing Record 48 of Set 9 | shache
# Processing Record 49 of Set 9 | jiancheng
# Processing Record 50 of Set 9 | atar
# Processing Record 1 of Set 10 | alekseyevsk
# Processing Record 2 of Set 10 | barentu
# Processing Record 3 of Set 10 | northam
# Processing Record 4 of Set 10 | ballitoville
# Processing Record 5 of Set 10 | mezen
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 10 | nemuro
# Processing Record 9 of Set 10 | cayenne
# Processing Record 10 of Set 10 | auki
# Processing Record 11 of Set 10 | thaba-tseka
# Processing Record 12 of Set 10 | hambantota
# Processing Record 13 of Set 10 | lancaster
# Processing Record 14 of Set 10 | nome
# Processing Record 15 of Set 10 | visby
# Processing Record 16 of Set 10 | marsa matruh
# Processing Record 17 of Set 10 | russell
# Processing Record 18 of Set 10 | bengkulu
# Processing Record 19 of Set 10 | alugan
# Processing Record 20 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 10 | aswan
# Processing Record 22 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 10 | zverinogolovskoye
# Processing Record 24 of Set 10 | chegdomyn
# Processing Record 25 of Set 10 | valparaiso
# Processing Record 26 of Set 10 | kalmeshwar
# Processing Record 27 of Set 10 | balabac
# Processing Record 28 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 29 of Set 10 | aripuana
# Processing Record 30 of Set 10 | jaru
# Processing Record 31 of Set 10 | ouricuri
# Processing Record 32 of Set 10 | copiapo
# Processing Record 33 of Set 10 | broome
# Processing Record 34 of Set 10 | launceston
# Processing Record 35 of Set 10 | lang son
# Processing Record 36 of Set 10 | ndele
# Processing Record 37 of Set 10 | anadyr
# Processing Record 38 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 10 | karratha
# Processing Record 40 of Set 10 | tura
# Processing Record 41 of Set 10 | evora
# Processing Record 42 of Set 10 | houma
# Processing Record 43 of Set 10 | provost
# Processing Record 44 of Set 10 | kiunga
# Processing Record 45 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 10 | mtimbira
# Processing Record 47 of Set 10 | lishui
# Processing Record 48 of Set 10 | kawalu
# Processing Record 49 of Set 10 | broken hill
# Processing Record 50 of Set 10 | siocon
# Processing Record 1 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 2 of Set 11 | gat
# Processing Record 3 of Set 11 | beckley
# Processing Record 4 of Set 11 | acarau
# Processing Record 5 of Set 11 | fernie
# Processing Record 6 of Set 11 | verkhnevilyuysk
# Processing Record 7 of Set 11 | hervey bay
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | galveston
# Processing Record 10 of Set 11 | wajir
# Processing Record 11 of Set 11 | rodrigues alves
# Processing Record 12 of Set 11 | geraldton
# Processing Record 13 of Set 11 | ponta delgada
# Processing Record 14 of Set 11 | mbaiki
# Processing Record 15 of Set 11 | ekibastuz
# Processing Record 16 of Set 11 | krasnyy chikoy
# Processing Record 17 of Set 11 | koslan
# Processing Record 18 of Set 11 | fort william
# Processing Record 19 of Set 11 | pak thong chai
# Processing Record 20 of Set 11 | homer
# Processing Record 21 of Set 11 | tupiza
# Processing Record 22 of Set 11 | atasu
# Processing Record 23 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 24 of Set 11 | at-bashi
# Processing Record 25 of Set 11 | asifabad
# Processing Record 26 of Set 11 | felanitx
# Processing Record 27 of Set 11 | asosa
# Processing Record 28 of Set 11 | la asuncion
# Processing Record 29 of Set 11 | jibuti
# Processing Record 30 of Set 11 | matamoros
# Processing Record 31 of Set 11 | viedma
# Processing Record 32 of Set 11 | camana
# Processing Record 33 of Set 11 | walvis bay
# Processing Record 34 of Set 11 | laurel
# Processing Record 35 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 36 of Set 11 | quiroga
# Processing Record 37 of Set 11 | farah
# Processing Record 38 of Set 11 | bulgan
# Processing Record 39 of Set 11 | basco
# Processing Record 40 of Set 11 | hirna
# Processing Record 41 of Set 11 | navahrudak
# Processing Record 42 of Set 11 | chapais
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | ewa beach
# Processing Record 45 of Set 11 | timmins
# Processing Record 46 of Set 11 | yangshe
# Processing Record 47 of Set 11 | balykshi
# Processing Record 48 of Set 11 | dalvik
# Processing Record 49 of Set 11 | seoul
# Processing Record 50 of Set 11 | shchebetovka
# Processing Record 1 of Set 12 | zhigalovo
# Processing Record 2 of Set 12 | matara
# Processing Record 3 of Set 12 | hurghada
# Processing Record 4 of Set 12 | kloulklubed
# Processing Record 5 of Set 12 | chico
# Processing Record 6 of Set 12 | tarnogskiy gorodok
# Processing Record 7 of Set 12 | revda
# Processing Record 8 of Set 12 | kopervik
# Processing Record 9 of Set 12 | haapiti
# Processing Record 10 of Set 12 | havoysund
# Processing Record 11 of Set 12 | rocha
# Processing Record 12 of Set 12 | norman wells
# Processing Record 13 of Set 12 | kalmunai
# Processing Record 14 of Set 12 | christiansburg
# Processing Record 15 of Set 12 | hyeres
# Processing Record 16 of Set 12 | laguna
# Processing Record 17 of Set 12 | mayskiy
# Processing Record 18 of Set 12 | belle glade
# Processing Record 19 of Set 12 | ojinaga
# Processing Record 20 of Set 12 | dunhua
# Processing Record 21 of Set 12 | taywarah
# Processing Record 22 of Set 12 | half moon bay
# Processing Record 23 of Set 12 | jalu
# Processing Record 24 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 12 | krasnokholm
# Processing Record 26 of Set 12 | itaqui
# Processing Record 27 of Set 12 | glenwood springs
# Processing Record 28 of Set 12 | palermo
# Processing Record 29 of Set 12 | praia
# Processing Record 30 of Set 12 | goderich
# Processing Record 31 of Set 12 | lubango
# Processing Record 32 of Set 12 | tecuala
# Processing Record 33 of Set 12 | vao
# Processing Record 34 of Set 12 | springbok
# Processing Record 35 of Set 12 | berlevag
# Processing Record 36 of Set 12 | tamandare
# Processing Record 37 of Set 12 | labytnangi
# Processing Record 38 of Set 12 | genhe
# Processing Record 39 of Set 12 | binga
# Processing Record 40 of Set 12 | salamiyah
# Processing Record 41 of Set 12 | zhuhai
# Processing Record 42 of Set 12 | sao joao da barra
# Processing Record 43 of Set 12 | jinchang
# Processing Record 44 of Set 12 | batagay
# Processing Record 45 of Set 12 | roma
# Processing Record 46 of Set 12 | cravo norte
# Processing Record 47 of Set 12 | jacareacanga
# Processing Record 48 of Set 12 | meulaboh
# Processing Record 49 of Set 12 | sawakin
# Processing Record 50 of Set 12 | bandarbeyla
# Processing Record 1 of Set 13 | obihiro
# Processing Record 2 of Set 13 | juba
# Processing Record 3 of Set 13 | gardendale
# Processing Record 4 of Set 13 | kharp
# Processing Record 5 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 13 | olonets
# Processing Record 7 of Set 13 | urumqi
# Processing Record 8 of Set 13 | maridi
# Processing Record 9 of Set 13 | qasigiannguit
# Processing Record 10 of Set 13 | portobelo
# Processing Record 11 of Set 13 | buba
# Processing Record 12 of Set 13 | eureka
# Processing Record 13 of Set 13 | vestmannaeyjar
# Processing Record 14 of Set 13 | kaduy
# Processing Record 15 of Set 13 | te anau
# Processing Record 16 of Set 13 | nuqui
# Processing Record 17 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 13 | lagoa
# Processing Record 19 of Set 13 | ekimchan
# Processing Record 20 of Set 13 | sioux lookout
# Processing Record 21 of Set 13 | cozumel
# Processing Record 22 of Set 13 | knysna
# Processing Record 23 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 13 | brewster
# Processing Record 25 of Set 13 | sorong
# Processing Record 26 of Set 13 | manbij
# Processing Record 27 of Set 13 | aguimes
# Processing Record 28 of Set 13 | mnogovershinnyy
# Processing Record 29 of Set 13 | sakakah
# Processing Record 30 of Set 13 | puerto asis
# Processing Record 31 of Set 13 | kieta
# Processing Record 32 of Set 13 | quelimane
# Processing Record 33 of Set 13 | laramie
# Processing Record 34 of Set 13 | sheffield
# Processing Record 35 of Set 13 | kailua
# Processing Record 36 of Set 13 | rio grande
# Processing Record 37 of Set 13 | miranda
# Processing Record 38 of Set 13 | namwala
# Processing Record 39 of Set 13 | moindou
# Processing Record 40 of Set 13 | alyangula
# Processing Record 41 of Set 13 | ust-shonosha
# Processing Record 42 of Set 13 | kununurra
# Processing Record 43 of Set 13 | labuhan
# Processing Record 44 of Set 13 | shitkino
# Processing Record 45 of Set 13 | caidian
# Processing Record 46 of Set 13 | namatanai
# Processing Record 47 of Set 13 | vila velha
# Processing Record 48 of Set 13 | never
# Processing Record 49 of Set 13 | tricase
# Processing Record 50 of Set 13 | stromness
# Processing Record 1 of Set 14 | ko samui
# Processing Record 2 of Set 14 | grand gaube
# Processing Record 3 of Set 14 | sukabumi
# Processing Record 4 of Set 14 | miri
# Processing Record 5 of Set 14 | alac
# Processing Record 6 of Set 14 | colwyn bay
# Processing Record 7 of Set 14 | north platte
# Processing Record 8 of Set 14 | sistranda
# Processing Record 9 of Set 14 | gazojak
# Processing Record 10 of Set 14 | quesnel
# Processing Record 11 of Set 14 | tigil
# Processing Record 12 of Set 14 | wanaka
# Processing Record 13 of Set 14 | sinnamary
# Processing Record 14 of Set 14 | victor harbor
# Processing Record 15 of Set 14 | afua
# Processing Record 16 of Set 14 | mala
# Processing Record 17 of Set 14 | aksha
# Processing Record 18 of Set 14 | zykovo
# Processing Record 19 of Set 14 | nuevitas
# Processing Record 20 of Set 14 | piopio
# Processing Record 21 of Set 14 | pendleton
# Processing Record 22 of Set 14 | mineiros
# Processing Record 23 of Set 14 | caraballeda
# Processing Record 24 of Set 14 | arkhangelsk
# Processing Record 25 of Set 14 | melilla
# Processing Record 26 of Set 14 | recsk
# Processing Record 27 of Set 14 | yima
# Processing Record 28 of Set 14 | forestville
# Processing Record 29 of Set 14 | annavasal
# Processing Record 30 of Set 14 | victoria point
# Processing Record 31 of Set 14 | turukhansk
# Processing Record 32 of Set 14 | altenholz
# Processing Record 33 of Set 14 | kurilsk
# Processing Record 34 of Set 14 | derzhavinsk
# Processing Record 35 of Set 14 | alexandria
# Processing Record 36 of Set 14 | nkhata bay
# Processing Record 37 of Set 14 | valdivia
# Processing Record 38 of Set 14 | santiago de cao
# Processing Record 39 of Set 14 | santa isabel do rio negro
# Processing Record 40 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 14 | inverell
# Processing Record 42 of Set 14 | amelia
# Processing Record 43 of Set 14 | cabadiangan
# Processing Record 44 of Set 14 | olinda
# Processing Record 45 of Set 14 | hirado
# Processing Record 46 of Set 14 | tautira
# Processing Record 47 of Set 14 | ghugus
# Processing Record 48 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 14 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 50 of Set 14 | amahai
# Processing Record 1 of Set 15 | iwanai
# Processing Record 2 of Set 15 | fare
# Processing Record 3 of Set 15 | lakes entrance
# Processing Record 4 of Set 15 | lensk
# Processing Record 5 of Set 15 | saint-augustin
# Processing Record 6 of Set 15 | ca mau
# Processing Record 7 of Set 15 | port elizabeth
# Processing Record 8 of Set 15 | zacualpan
# Processing Record 9 of Set 15 | lima
# Processing Record 10 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | nisia floresta
# Processing Record 13 of Set 15 | lorengau
# Processing Record 14 of Set 15 | izhma
# Processing Record 15 of Set 15 | kamenka
# Processing Record 16 of Set 15 | kingston
# Processing Record 17 of Set 15 | bektemir
# Processing Record 18 of Set 15 | ishigaki
# Processing Record 19 of Set 15 | abu dhabi
# Processing Record 20 of Set 15 | ippy
# Processing Record 21 of Set 15 | opunake
# Processing Record 22 of Set 15 | inuvik
# Processing Record 23 of Set 15 | astana
# Processing Record 24 of Set 15 | santa maria
# Processing Record 25 of Set 15 | sciacca
# Processing Record 26 of Set 15 | disna
# Processing Record 27 of Set 15 | buin
# Processing Record 28 of Set 15 | samarai
# Processing Record 29 of Set 15 | okha
# Processing Record 30 of Set 15 | lota
# Processing Record 31 of Set 15 | natchitoches
# Processing Record 32 of Set 15 | dire dawa
# Processing Record 33 of Set 15 | buckeye
# Processing Record 34 of Set 15 | asyut
# Processing Record 35 of Set 15 | port-cartier
# Processing Record 36 of Set 15 | yeppoon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Macomer  40.2620    8.7699     53.65     overcast clouds        83
# 1      Khatanga  71.9667  102.5000     -4.63     overcast clouds        99
# 2    Codrington -38.2667  141.9667     70.47          light rain        85
# 3       Rikitea -23.1203 -134.9692     71.58       moderate rain        90
# 4    Oranjemund -28.5500   16.4333     58.59           clear sky        87
# 5   New Norfolk -42.7826  147.0587     82.92       broken clouds        34
# 6   Port Alfred -33.5906   26.8910     59.18     overcast clouds        97
# 7  Saint-Pierre -21.3393   55.4781     81.57           clear sky        65
# 8       Changji  44.0167   87.3167     41.79           clear sky        75
# 9         Vaini -21.2000 -175.2000     78.96       broken clouds        89
#
#    Cloudiness  Wind Speed Country
# 0         100        0.81      IT
# 1         100        6.26      RU
# 2          97       11.59      AU
# 3         100       11.03      PF
# 4          10       10.31      NA
# 5          64       11.01      AU
# 6         100       12.06      ZA
# 7           0       13.80      RE
# 8           0        2.24      CN
# 9          75        6.91      TO

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_df=city_data_df[new_order]

# Display sample data
city_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Macomer      IT  40.2620    8.7699     53.65        83         100
# 1        Khatanga      RU  71.9667  102.5000     -4.63        99         100
# 2      Codrington      AU -38.2667  141.9667     70.47        85          97
# 3         Rikitea      PF -23.1203 -134.9692     71.58        90         100
# 4      Oranjemund      NA -28.5500   16.4333     58.59        87          10
# ..            ...     ...      ...       ...       ...       ...         ...
# 673     Dire Dawa      ET   9.5931   41.8661     73.20        57          44
# 674       Buckeye      US  33.3703 -112.5838     59.18        79         100
# 675         Asyut      EG  27.1810   31.1837     62.11        64           0
# 676  Port-Cartier      CA  50.0334  -66.8654     33.75        72         100
# 677       Yeppoon      AU -23.1333  150.7333     78.58        61          67
#
#      Wind Speed Current Description
# 0          0.81     overcast clouds
# 1          6.26     overcast clouds
# 2         11.59          light rain
# 3         11.03       moderate rain
# 4         10.31           clear sky
# ..          ...                 ...
# 673        4.63    scattered clouds
# 674        5.75     overcast clouds
# 675        5.75           clear sky
# 676       10.11     overcast clouds
# 677       16.80       broken clouds
#
# [678 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678 entries, 0 to 677
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 678 non-null    object
#  1   Country              678 non-null    object
#  2   Lat                  678 non-null    float64
#  3   Lng                  678 non-null    float64
#  4   Max Temp             678 non-null    float64
#  5   Humidity             678 non-null    int64
#  6   Cloudiness           678 non-null    int64
#  7   Wind Speed           678 non-null    float64
#  8   Current Description  678 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 47.8+ KB

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
